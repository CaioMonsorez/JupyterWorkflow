# %%
# importar o pandas

import pandas as pd

# %%
# importar o arquivo csv

dados = pd.read_csv("epi.csv", encoding = "UTF-8", sep = ";")

# %%
# Head(50) lista as 50 primeiras linhas

dados.head(50)
# Out:
#    Material    Dt.Saída  Nº Pedido Requisitante / Destino Unidade Quantidade  \
# 0    Álcool  19/03/2020     308748                   Acre   Litro        9,6
# 1    Álcool  19/03/2020     308748                   Acre   Litro         42
# 2    Álcool  19/03/2020     308499                   Acre   Litro         12
# 3    Álcool  19/03/2020     308500                   Acre   Litro         12
# 4    Álcool  25/03/2020     309483                   Acre   Litro         48
# 5    Álcool  28/03/2020     309979                   Acre   Litro       19,2
# 6    Álcool  28/03/2020     309979                   Acre   Litro         18
# 7    Álcool  31/03/2020     310553                   Acre   Litro        132
# 8    Álcool  10/04/2020     311433                   Acre   Litro       12,6
# 9    Álcool  15/04/2020     311873                   Acre   Litro          5
# 10   Álcool  15/04/2020     311873                   Acre   Litro          4
# ...

# %%
# Columns lista todas as colunas do arquivo

dados.columns
# Out:
# Index(['Material', 'Dt.Saída', 'Nº Pedido', 'Requisitante / Destino',
#        'Unidade', 'Quantidade', 'Status'],
#       dtype='object')

# %%
# lista os arrays e seus valores

dados.values
# Out:
# array([['Álcool', '19/03/2020', 308748, ..., 'Litro', '9,6', 'Entregue'],
#        ['Álcool', '19/03/2020', 308748, ..., 'Litro', '42', 'Entregue'],
#        ['Álcool', '19/03/2020', 308499, ..., 'Litro', '12', 'Entregue'],
#        ...,
#        ['Teste Rápido', '12/11/2020', 666666, ..., 'Teste', '140',
#         'Entregue'],
#        ['Teste Rápido', '14/11/2020', 666666, ..., 'Teste', '136580',
#         'Entregue'],
#        ['Teste Rápido', '18/11/2020', 666666, ..., 'Teste', '7200',
#         'Entregue']], dtype=object)

# %%
# Localiza os dados da linha 0

dados.loc[1]
# Out:
# Material                      Álcool
# Dt.Saída                  19/03/2020
# Nº Pedido                     308748
# Requisitante / Destino          Acre
# Unidade                        Litro
# Quantidade                        42
# Status                      Entregue
# Name: 1, dtype: object

# %%
# Localiza os dados da linha 1, 2 e 3

dados.loc[[1,2,3]]
# Out:
#   Material    Dt.Saída  Nº Pedido Requisitante / Destino Unidade Quantidade  \
# 1   Álcool  19/03/2020     308748                   Acre   Litro         42
# 2   Álcool  19/03/2020     308499                   Acre   Litro         12
# 3   Álcool  19/03/2020     308500                   Acre   Litro         12
#
#      Status
# 1  Entregue
# 2  Entregue
# 3  Entregue

# %%
# localiza lista os dados da linha ate ate a 20

dados.loc[10:20]
# Out:
#    Material    Dt.Saída  Nº Pedido Requisitante / Destino Unidade Quantidade  \
# 10   Álcool  15/04/2020     311873                   Acre   Litro          4
# 11   Álcool  15/04/2020     311873                   Acre   Litro      153,5
# 12   Álcool  23/04/2020     312962                   Acre   Litro        798
# 13   Álcool  30/04/2020     313999                   Acre   Litro       1068
# 14   Álcool  14/05/2020     315513                   Acre   Litro         96
# 15   Álcool  19/03/2020     308752                Alagoas   Litro       28,8
# 16   Álcool  19/03/2020     308752                Alagoas   Litro        156
# 17   Álcool  19/03/2020     308531                Alagoas   Litro         12
# 18   Álcool  25/03/2020     309488                Alagoas   Litro       28,8
# 19   Álcool  25/03/2020     309488                Alagoas   Litro        156
# 20   Álcool  28/03/2020     309983                Alagoas   Litro       86,4
#
#       Status
# 10  Entregue
# 11  Entregue
# ...

# %%
# localiza lista os dados da linha 10 ate a 20 de 2 em 2

dados.loc[10:20:2]
# Out:
#    Material    Dt.Saída  Nº Pedido Requisitante / Destino Unidade Quantidade  \
# 10   Álcool  15/04/2020     311873                   Acre   Litro          4
# 12   Álcool  23/04/2020     312962                   Acre   Litro        798
# 14   Álcool  14/05/2020     315513                   Acre   Litro         96
# 16   Álcool  19/03/2020     308752                Alagoas   Litro        156
# 18   Álcool  25/03/2020     309488                Alagoas   Litro       28,8
# 20   Álcool  28/03/2020     309983                Alagoas   Litro       86,4
#
#       Status
# 10  Entregue
# 12  Entregue
# 14  Entregue
# 16  Entregue
# 18  Entregue
# 20  Entregue

# %%
# localiza os 10 primeiros itens das colunas selecionadas

dados.loc[1:10, ['Material','Unidade','Quantidade']]
# Out:
#    Material Unidade Quantidade
# 1    Álcool   Litro         42
# 2    Álcool   Litro         12
# 3    Álcool   Litro         12
# 4    Álcool   Litro         48
# 5    Álcool   Litro       19,2
# 6    Álcool   Litro         18
# 7    Álcool   Litro        132
# 8    Álcool   Litro       12,6
# 9    Álcool   Litro          5
# 10   Álcool   Litro          4

# %%
dados.describe()
# Out:
#           Nº Pedido
# count    6404.00000
# mean   317670.57792
# std     21093.10796
# min    308301.00000
# 25%    310615.75000
# 50%    315593.00000
# 75%    321453.00000
# max    666666.00000
